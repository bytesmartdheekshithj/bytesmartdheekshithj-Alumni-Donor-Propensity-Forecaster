# %%
import pandas as pd
import numpy as np
import os

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-4227d008-ea5e-4dde-a975-67855c0bdabc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4227d008-ea5e-4dde-a975-67855c0bdabc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'alumni_donor_dataset_2025.csv', 'sample_data']

# %%
dataset_path = "alumni_donor_dataset_2025.csv"

df = pd.read_csv(dataset_path)

print("Dataset loaded successfully!")
print("Shape:", df.shape)
# Out:
# Dataset loaded successfully!
# Shape: (10000, 18)

# %%
df.head()
# Out:
#    Alumni_ID  Age  Gender  Graduation_Year Degree_Level         Major  \
# 0  ALM000001   52    Male             1973     Bachelor     Education
# 1  ALM000002   42    Male             2023       Master      Business
# 2  ALM000003   54    Male             1973     Bachelor      Business
# 3  ALM000004   67    Male             1997       Master           Law
# 4  ALM000005   41  Female             1972     Bachelor  Liberal Arts
#
#   Alumni_Status Email_Available Phone_Available Wealth_Rating Income_Bracket  \
# 0      Inactive             Yes             Yes             C          <$50K
# 1      Inactive             Yes             Yes             B    $100K-$150K
# 2        Active             Yes             Yes             C     $50K-$100K
# 3  Lost Contact             Yes             Yes            B+         >$500K
# 4      Inactive             Yes             Yes            B+     $50K-$100K
#
#    Event_Attendance  Email_Open_Rate             Location  \
# ...

# %%
print("Columns in dataset:")

for column in df.columns:
    print(column)
# Out:
# Columns in dataset:
# Alumni_ID
# Age
# Gender
# Graduation_Year
# Degree_Level
# Major
# Alumni_Status
# Email_Available
# Phone_Available
# Wealth_Rating
# Income_Bracket
# Event_Attendance
# Email_Open_Rate
# Location
# Consecutive_Giving_Years
# Donation_Last_Year_2024
# Total_Lifetime_Giving
# Is_Donor_2025

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Alumni_ID                 10000 non-null  object
#  1   Age                       10000 non-null  int64
#  2   Gender                    10000 non-null  object
#  3   Graduation_Year           10000 non-null  int64
#  4   Degree_Level              10000 non-null  object
#  5   Major                     10000 non-null  object
#  6   Alumni_Status             10000 non-null  object
#  7   Email_Available           10000 non-null  object
#  8   Phone_Available           10000 non-null  object
#  9   Wealth_Rating             10000 non-null  object
#  10  Income_Bracket            10000 non-null  object
#  11  Event_Attendance          10000 non-null  int64
#  12  Email_Open_Rate           10000 non-null  float64
# ...

# %%
missing_values = df.isnull().sum()

print("Missing values:")
print(missing_values)
# Out:
# Missing values:
# Alumni_ID                   0
# Age                         0
# Gender                      0
# Graduation_Year             0
# Degree_Level                0
# Major                       0
# Alumni_Status               0
# Email_Available             0
# Phone_Available             0
# Wealth_Rating               0
# Income_Bracket              0
# Event_Attendance            0
# Email_Open_Rate             0
# Location                    0
# Consecutive_Giving_Years    0
# Donation_Last_Year_2024     0
# Total_Lifetime_Giving       0
# Is_Donor_2025               0
# dtype: int64

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
print(df["Is_Donor_2025"].value_counts())
# Out:
# Is_Donor_2025
# Yes    5740
# No     4260
# Name: count, dtype: int64

# %%
print(df["Is_Donor_2025"].value_counts(normalize=True) * 100)
# Out:
# Is_Donor_2025
# Yes    57.4
# No     42.6
# Name: proportion, dtype: float64

# %%
output_path = "alumni_donor_dataset_2025.csv"

df.to_csv(
    output_path,
    index=False
)

print("Dataset saved successfully!")
print("File:", output_path)
print("Shape:", df.shape)
# Out:
# Dataset saved successfully!
# File: alumni_donor_dataset_2025.csv
# Shape: (10000, 18)

# %%
from google.colab import files

files.download("alumni_donor_dataset_2025.csv")

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
project_path = "/content/drive/MyDrive/Alumni_Donor_Propensity_Forecaster"

os.makedirs(project_path, exist_ok=True)

print("Project folder created:")
print(project_path)
# Out:
# Project folder created:
# /content/drive/MyDrive/Alumni_Donor_Propensity_Forecaster

# %%
import os

project_path = "/content/drive/MyDrive/Alumni_Donor_Propensity_Forecaster"

os.makedirs(project_path, exist_ok=True)
os.makedirs(os.path.join(project_path, "data"), exist_ok=True)
os.makedirs(os.path.join(project_path, "models"), exist_ok=True)
os.makedirs(os.path.join(project_path, "results"), exist_ok=True)

print("Folders created successfully!")
# Out:
# Folders created successfully!

# %%
drive_dataset_path = (
    project_path +
    "/data/alumni_donor_dataset_2025.csv"
)

df.to_csv(
    drive_dataset_path,
    index=False
)

print("Dataset saved to Google Drive!")
print(drive_dataset_path)
# Out:
# Dataset saved to Google Drive!
# /content/drive/MyDrive/Alumni_Donor_Propensity_Forecaster/data/alumni_donor_dataset_2025.csv
